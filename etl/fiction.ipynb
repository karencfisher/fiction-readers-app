# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/books_data.csv')
df = df.dropna()
df.rename(columns={'publishedDate': 'yearPublished', 'ratingsCount': 'avgRating', 
                   'description': 'synopsis', 'image': 'coverImg'}, inplace=True)
df.drop(columns=['previewLink'], inplace=True)
df.head()
# Out:
#                                                 Title  \
# 5   The Church of Christ: A Biblical Ecclesiology ...
# 31  Voices from the Farm: Adventures in Community ...
# 33                            The Battleship Bismarck
# 42                            Tess and the Highlander
# 43   Beginner's Yoruba (Hippocrene Beginner's Series)
#
#                                              synopsis  \
# 5   In The Church of Christ: A Biblical Ecclesiolo...
# 31  Twenty-five years ago, at the height of the co...
# 33  The Bismarck is perhaps the most famous – and ...
# 42  In 1543, on a windswept isle off of Scotland, ...
# 43  "Beginner's Yoruba" is now available with two ...
#
#                     authors  \
# 5      ['Everett Ferguson']
# 31          ['Rupert Fike']
# 33     ['Stefan Draminski']
# 42       ['May Mcgoldrick']
# 43  ['Kayode J. Fakinlede']
#
#                                              coverImg  \
# 5   http://books.google.com/books/content?id=kVqRa...
# 31  http://books.google.com/books/content?id=IjTAB...
# 33  http://books.google.com/books/content?id=nxttD...
# 42  http://books.google.com/books/content?id=VmCRS...
# 43  http://books.google.com/books/content?id=xLe4n...
#
#                      publisher yearPublished  \
# 5   Wm. B. Eerdmans Publishing          1996
# 31     Book Publishing Company    2012-08-21
# 33       Bloomsbury Publishing    2018-09-20
# 42              Harper Collins       2002-11
# 43            Hippocrene Books          2005
#
#                                              infoLink  \
# 5   http://books.google.nl/books?id=kVqRaiPlx88C&d...
# 31  https://play.google.com/store/books/details?id...
# 33  https://play.google.com/store/books/details?id...
# 42  http://books.google.nl/books?id=VmCRSPmY3WkC&d...
# 43  http://books.google.nl/books?id=xLe4nWzeSw0C&d...
#
#                        categories  avgRating
# 5                    ['Religion']        5.0
# 31  ['Biography & Autobiography']        1.0
# 33                    ['History']        1.0
# 42           ['Juvenile Fiction']        2.0
# 43     ['Foreign Language Study']        1.0

# %% [markdown]
# Clear avgRating to 0, and convert published dates to year published

# %%
df['avgRating'] = 0
df['avgRating'] = df['avgRating'].astype(int)
df['yearPublished'] = df['yearPublished'].apply(lambda x: x.split('-')[0])
df['yearPublished'] = df['yearPublished'].astype(int)

# %% [markdown]
# Clean up categories and authors. Remove any titles with multiple categories and authors

# %%
df['categories'] = df['categories'].apply(lambda x: x.replace('[', '').replace(']', '').replace("'", "").split(','))
df = df[df['categories'].apply(len) == 1]
df['categories'] = df['categories'].apply(lambda x: x[0])

df['authors'] = df['authors'].apply(lambda x: x.replace('[', '').replace(']', '').replace("'", "").split(','))
df = df[df['authors'].apply(len) == 1]
df['authors'] = df['authors'].apply(lambda x: x[0].replace('"', ''))

df['publisher'] = df['publisher'].apply(lambda x: x.strip().replace(',', ''))

df.rename(columns={'categories': 'category', 'authors': 'author'}, inplace=True)

# %% [markdown]
# Filter to Fiction books

# %%
fiction_df = df[df['category'] == "Fiction"]
fiction_df.drop(columns=['category'], inplace=True)
fiction_df['genre'] = ''
print(f'{fiction_df.shape[0]} fiction books')
fiction_df.head()
# Out:
# 10354 fiction books
#                                            Title  \
# 83   Perry Mason in the Case of Too Many Murders
# 115                          From Potter's Field
# 144                               Edge of Danger
# 155                                    Dead Sexy
# 196                                Days of Grass
#
#                                               synopsis             author  \
# 83   A Los Angeles businessman kills his dinner com...    Thomas Chastain
# 115  The sixth book in the Kay Scarpetta series, fr...  Patricia Cornwell
# 144  The action-packed new Sean Dillon novel. Maste...       Jack Higgins
# 155  In The Still Of The Night The city is in a pan...      Amanda Ashley
# 196  The free humans lived underground, secretive, ...         Tanith Lee
#
#                                               coverImg         publisher  \
# 83   http://books.google.com/books/content?id=oOdmG...        Avon Books
# 115  http://books.google.com/books/content?id=prefg...       Hachette UK
# 144  http://books.google.com/books/content?id=OgwoC...  HarperCollins UK
# 155  http://books.google.com/books/content?id=AiRjA...       Zebra Books
# 196  http://books.google.com/books/content?id=r2mgn...       Hachette UK
#
#      yearPublished                                           infoLink  \
# 83            1990  http://books.google.nl/books?id=oOdmGU8i_H8C&d...
# 115           2008  https://play.google.com/store/books/details?id...
# 144           2015  https://play.google.com/store/books/details?id...
# 155           2013  https://play.google.com/store/books/details?id...
# 196           2013  https://play.google.com/store/books/details?id...
#
#      avgRating genre
# 83           0
# 115          0
# 144          0
# 155          0
# 196          0

# %% [markdown]
# Randomly sample 500 books

# %%
fiction_small_df = fiction_df.sample(n=500, random_state=5)

# %% [markdown]
# Define 13 genres

# %%
genre_labels = [
    "Contemporary Fiction",
    "Literary Fiction",
    "Mystery/Thriller",
    "Historical Fiction",
    "Science Fiction",
    "Fantasy",
    "Romance",
    "Young Adult Fiction",
    "Dystopian Fiction",
    "Horror",
    "Magical Realism",
    "Adventure Fiction",
    "Miscellaneous Fiction",
    "Nonfiction"
]

# %% [markdown]
# Invite gpt-4o-mini to categorize our books into genres

# %%
from openai import OpenAI
from key import key


def make_genres(df, columns, labels):
    n = df.shape[0]
    client = OpenAI(api_key=key)

    genres = []
    count = 1
    for _, row in df.iterrows():
        count += 1
        texts = []
        for column in columns:
            texts.append(row[column])
        article = ' - '.join(texts)
        
        prompt = f'''
    Categorize the following book, by <author> - <title> - <synopsis>:

    ```{article}```

    Into one of the following genres:

    {labels}

    Any example that does not fit the others goes into "Miscellaneous fiction". Return only the genre name.

    '''
        completion = client.chat.completions.create(
            model="gpt-4o-mini",
            temperature=0,
            messages = [
                {'role': 'user', 'content': prompt}
            ]
        )

        genres.append(completion.choices[0].message.content)
        print(f'\rEvaluated {int(count / n * 100)}%', end='')
    print('\ndone!')
        
    df['genre'] = genres

# %%
make_genres(fiction_small_df, ['author', 'Title', 'synopsis'], genre_labels)
# Out:
# Evaluated 100%
# done!

# %%
fiction_small_df.head(10)
# Out:
#                                                     Title  \
# 161419                                      I am the Clay
# 120175                         Bergdorf Blondes : A Novel
# 66430     O Little Town of Maggody: An Arly Hanks Mystery
# 87894                                  Little Myth Marker
# 99265                   Winter Winds (Seaside Seasons #4)
# 34674                     The Jury (Paul Madriani Novels)
# 32453                                            Defector
# 100535                                     The Shadow Box
# 137674  Adolescente: La Clave para ser Libre y Feliz (...
# 20898   Blow Negative ! ("The Best Novel of the Navy S...
#
#                                                  synopsis         author  \
# 161419  “[Chaim] Potok writes powerfully about the suf...    Chaim Potok
# 120175  Meet moi, 'a champagne bubble of a girl about ...     Plum Sykes
# 66430   Country music, greed, and the unique madness o...      Joan Hess
# 87894   Skeeve, a young magician, and Aahz, his demon ...  Robert Asprin
# 99265   In Winter Winds, Gayle Roper concludes her del...    Gayle Roper
# 34674   The Attorney, which marked the return of Steve...  Steve Martini
# 32453   In Moscow Rules Gabriel Allon went up against ...   Daniel Silva
# 100535  Preparing for an exhibit that includes a piece...    Luanne Rice
# 137674  "Nineteen Eighty-Four: A Novel", often publish...  George Orwell
# 20898   James Webb’s classic, scorching novel of the V...     James Webb
#
#                                                  coverImg  \
# 161419  http://books.google.com/books/content?id=Tl6FU...
# 120175  http://books.google.com/books/content?id=DmRMD...
# 66430   http://books.google.com/books/content?id=AUAED...
# 87894   http://books.google.com/books/content?id=Ta_z_...
# 99265   http://books.google.com/books/content?id=RQuZc...
# 34674   http://books.google.com/books/content?id=8Cc_L...
# 32453   http://books.google.com/books/content?id=FpJbi...
# 100535  http://books.google.com/books/content?id=5PRhz...
# 137674  http://books.google.com/books/content?id=PEpoE...
# 20898   http://books.google.com/books/content?id=uZSOD...
#
#                     publisher  yearPublished  \
# 161419                Fawcett           2010
# 120175  Bloomsbury Publishing           2018
# 66430         Open Road Media           2016
# 87894               Ace Books           2006
# 99265               Multnomah           2011
# 34674                 Penguin           2002
# 32453                 Penguin           2009
# 100535        Thomas & Mercer           2021
# 137674                 epubli           2021
# 20898                  Canelo           2019
#
#                                                  infoLink  avgRating  \
# 161419  https://play.google.com/store/books/details?id...          0
# 120175  https://play.google.com/store/books/details?id...          0
# 66430   https://play.google.com/store/books/details?id...          0
# 87894   http://books.google.com/books?id=Ta_z_X30_eoC&...          0
# 99265   https://play.google.com/store/books/details?id...          0
# 34674   https://play.google.com/store/books/details?id...          0
# 32453   https://play.google.com/store/books/details?id...          0
# 100535  http://books.google.com/books?id=5PRhzQEACAAJ&...          0
# 137674  https://play.google.com/store/books/details?id...          0
# 20898   http://books.google.com/books?id=uZSODwAAQBAJ&...          0
#
#                        genre
# 161419    Historical Fiction
# 120175  Contemporary Fiction
# 66430       Mystery/Thriller
# 87894                Fantasy
# 99265                Romance
# 34674       Mystery/Thriller
# 32453       Mystery/Thriller
# 100535      Mystery/Thriller
# 137674     Dystopian Fiction
# 20898     Historical Fiction

# %% [markdown]
# A few non-fiction books may have snuck by

# %%
fiction_small_df[fiction_small_df['genre'] == 'Nonfiction']
# Out:
#                                                     Title  \
# 120351                                       Sex a Baller
# 37135   The Portable Enlightenment Reader (The Viking ...
# 86584                  My Secret Book (Hesperus Classics)
# 187902                                The pump house gang
# 195810                         Shakespeare Never Did This
#
#                                                  synopsis              author  \
# 120351  Mysterious Luva has sexed them all! Ball playe...     Mysterious Luva
# 37135   Presents writings from such figures as Immanue...             Various
# 86584   Written by one of the greatest poets of all ti...  Francesco Petrarca
# 187902  A sprawling collection of essays about the sub...           Tom Wolfe
# 195810  An account of Charles Bukowski's 1978 European...    Charles Bukowski
#
#                                                  coverImg          publisher  \
# 120351  http://books.google.com/books/content?id=MMJ1A...  Black Pearl Books
# 37135   http://books.google.com/books/content?id=f4oFA...   Penguin Classics
# 86584   http://books.google.com/books/content?id=YkpdA...     Hesperus Press
# 187902  http://books.google.com/books/content?id=Mjh3E...            Picador
# 195810  http://books.google.com/books/content?id=f-bqs...               Ecco
#
#         yearPublished                                           infoLink  \
# 120351           2004  http://books.google.nl/books?id=MMJ1AAAACAAJ&d...
# 37135            1995  http://books.google.com/books?id=f4oFAQAAIAAJ&...
# 86584            2002  http://books.google.com/books?id=YkpdAAAAMAAJ&...
# 187902           2022  http://books.google.com/books?id=Mjh3EAAAQBAJ&...
# 195810           2002  http://books.google.com/books?id=f-bqsgEACAAJ&...
#
#         avgRating       genre
# 120351          0  Nonfiction
# 37135           0  Nonfiction
# 86584           0  Nonfiction
# 187902          0  Nonfiction
# 195810          0  Nonfiction

# %%
fiction_small_df = fiction_small_df[fiction_small_df['genre'] != 'Nonfiction']
fiction_small_df.shape
# Out:
# (495, 9)

# %%
authors = fiction_small_df['author'].unique().tolist()
authors.sort()
fiction_small_df['authorId'] = fiction_small_df['author'].apply(lambda x: authors.index(x))

publishers = fiction_small_df['publisher'].unique().tolist()
publishers.sort()
fiction_small_df['publisherId'] = fiction_small_df['publisher'].apply(lambda x: publishers.index(x))

genres = fiction_small_df['genre'].unique().tolist()
genres.sort()
fiction_small_df['genreId'] = fiction_small_df['genre'].apply(lambda x: genres.index(x))

fiction_small_df.drop(columns=['author', 'publisher', 'genre'], inplace=True)
fiction_small_df
# Out:
#                                                   Title  \
# 161419                                    I am the Clay
# 120175                       Bergdorf Blondes : A Novel
# 66430   O Little Town of Maggody: An Arly Hanks Mystery
# 87894                                Little Myth Marker
# 99265                 Winter Winds (Seaside Seasons #4)
# ...                                                 ...
# 12546                                 A Season of Grace
# 173549  The Horus Heresy Vol. III: Visions of Treachery
# 206363                                    Sisters Found
# 156006                                The Story of Ruth
# 71787                               McDonough,: A novel
#
#                                                  synopsis  \
# 161419  “[Chaim] Potok writes powerfully about the suf...
# 120175  Meet moi, 'a champagne bubble of a girl about ...
# 66430   Country music, greed, and the unique madness o...
# 87894   Skeeve, a young magician, and Aahz, his demon ...
# 99265   In Winter Winds, Gayle Roper concludes her del...
# ...                                                   ...
# 12546   In 1910 Minnesota, Nilda Carlson's dreams are ...
# 173549  A stunning artefact book for fans of the Horus...
# 206363  Follows triplets Hope, Faith, and Charity, who...
# 156006  PEN/Hemingway Award Winner: An “enthralling” n...
# 71787   “A warm, heartfelt novel about what it means t...
#
#                                                  coverImg  yearPublished  \
# 161419  http://books.google.com/books/content?id=Tl6FU...           2010
# 120175  http://books.google.com/books/content?id=DmRMD...           2018
# 66430   http://books.google.com/books/content?id=AUAED...           2016
# 87894   http://books.google.com/books/content?id=Ta_z_...           2006
# 99265   http://books.google.com/books/content?id=RQuZc...           2011
# ...                                                   ...            ...
# 12546   http://books.google.com/books/content?id=dhFYD...           2018
# 173549  http://books.google.com/books/content?id=x6e0N...           2014
# 206363  http://books.google.com/books/content?id=87wyA...           2013
# 156006  http://books.google.com/books/content?id=Qp7iB...           2014
# 71787   http://books.google.com/books/content?id=VgBjB...           2015
#
#                                                  infoLink  avgRating  \
# 161419  https://play.google.com/store/books/details?id...          0
# 120175  https://play.google.com/store/books/details?id...          0
# 66430   https://play.google.com/store/books/details?id...          0
# 87894   http://books.google.com/books?id=Ta_z_X30_eoC&...          0
# 99265   https://play.google.com/store/books/details?id...          0
# ...                                                   ...        ...
# 12546   http://books.google.nl/books?id=dhFYDwAAQBAJ&d...          0
# 173549  http://books.google.com/books?id=x6e0NAEACAAJ&...          0
# 206363  http://books.google.com/books?id=87wyAgAAQBAJ&...          0
# 156006  https://play.google.com/store/books/details?id...          0
# 71787   https://play.google.com/store/books/details?id...          0
#
#         authorId  publisherId  genreId
# 161419        66           68        4
# 120175       340           32        1
# 66430        199          130        9
# 87894        358            5        3
# 99265        148          117       10
# ...          ...          ...      ...
# 12546        250           17        4
# 173549         8           71       11
# 206363       200           81       10
# 156006       183           80        6
# 71787        285          105        1
#
# [495 rows x 9 columns]

# %% [markdown]
# Write out CSV files

# %%
fiction_small_df.to_csv('../data/books.csv', index=False)

authors_df = pd.DataFrame(authors, columns=['authorName'])
authors_df.to_csv('../data/authors.csv', index=False)

publishers_df = pd.DataFrame(publishers, columns=['publisherName'])
publishers_df.to_csv('../data/publishers.csv', index=False)

genres_df = pd.DataFrame(genres, columns=['genre'])
genres_df.to_csv('../data/genres.csv', index=False)
